# %% [markdown]
# <a href="https://colab.research.google.com/github/qykuh00/data-science-toolkit-w1/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to data science")
# Out:
# Welcome to data science
